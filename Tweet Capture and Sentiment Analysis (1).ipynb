# %%
import tweepy
import numpy as np
from textblob import TextBlob

consumer_key='jbhN62NNooXUrQ1pInuQEO08D'
consumer_secret='K9PR2H96lmAME8nkiCvfsGWuZjwa2TtrkV9SzzBkvEJvjUDB0O'

access_token='780358704642203649-iFeBFnFmE3vTupPvNQRRwfkfkPIg6WO'
access_token_secret='E4S0og7F6bJlUPYAlrF5tBhkT8bxAXyYSVyTubvM5TCvF'

auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

api = tweepy.API(auth)

def is_english(text):
    if text.detect_language() == 'en':
        return True
    return False

def tweet_analysis(query):
    tweets = tweepy.Cursor(api.search, q=query + " -filter:retweets").items(20)

    subjectivities = []
    polarities = []

    for tweet in tweets:
        phrase = TextBlob(tweet.text)

        if not is_english(phrase):
            phrase = TextBlob(str(phrase.translate(to='en')))

        if phrase.sentiment.polarity != 0.0 and phrase.sentiment.subjectivity != 0.0:
            polarities.append(phrase.sentiment.polarity)
            subjectivities.append(phrase.sentiment.subjectivity)

        print('Tweet: ' + tweet.text)
        print('Polarity: ' + str(phrase.sentiment.polarity) + ' \ Subjectivity: ' + str(phrase.sentiment.subjectivity))
        print('.....................')

    return {'polarity':polarities, 'subjectivity':subjectivities}

def get_weighted_polarity_mean(valid_tweets):
    return np.average(valid_tweets['polarity'],weights=valid_tweets['subjectivity'])

def get_polarity_mean(valid_tweets):
    return np.mean(valid_tweets['polarity'])

def print_result(mean):
    if mean > 0.0:
        print('POSITIVE')
    elif mean == 0.0:
        print('NEUTRAL')
    else:
        print('NEGATIVE')

if __name__ == "__main__":
    query = input("Enter a query to find: ")
    analysis = tweet_analysis(query)

    print('WEIGHTED MEAN: ' + str(get_weighted_polarity_mean(analysis)))
    print_result(get_weighted_polarity_mean(analysis))

    print('MEAN: ' + str(get_polarity_mean(analysis)))
    print_result(get_polarity_mean(analysis))
# Out:
# Enter a query to find: nba
# Tweet: @NBA your refs suck.  Fix the problem https://t.co/ygxA3CrWbJ
# Polarity: 0.0 \ Subjectivity: 0.0
# .....................
# Tweet: Check out my broadcast from my PlayStation 4! #PS4live (NBA 2K19)  live at https://t.co/TnvapTtjKa
# Polarity: 0.13636363636363635 \ Subjectivity: 0.5
# .....................
# Tweet: https://t.co/5tEXBATZdv
# Polarity: 0.0 \ Subjectivity: 0.0
# .....................
# Tweet: Iniciamos !!! #NBA #NBAxESPN
# #Nuggets vs #Spurs
# Junto a @AlvaroNBAMartin
# ESPN https://t.co/sLv9CTzGrg https://t.co/AiQqsaMNaU
# Polarity: 0.0 \ Subjectivity: 0.0
# .....................
# Tweet: @IcySimmons @NBA Nah Kat, embiid then Jokic
# Polarity: 0.0 \ Subjectivity: 0.0
# .....................
# Tweet: @NBA FUCK UR FUCKEN REFS AGAIN U FKN POOC ASS BITCHES
# Polarity: -0.4 \ Subjectivity: 0.6
# .....................
# Tweet: https://t.co/WVbUHAInBw
# Polarity: 0.0 \ Subjectivity: 0.0
# .....................
# Tweet: #Heat #GoranDragic hasnt been the same since his last injury. I thought with #TylerJohnson departing he would excel further. #NBA
# Polarity: 0.0 \ Subjectivity: 0.23055555555555554
# .....................
# Tweet: @criscyborg @ufc @NFL @NBA @MLB @espn Cyborg don’t preach and tell others how to live unless you are perfect, build… https://t.co/dcFN1sZWXK
# Polarity: 0.5681818181818181 \ Subjectivity: 0.75
# .....................
# Tweet: @espn We just gonna ignore him walking halfway down the court? Does the @NBA call traveling anymore or is that less exciting?
# Polarity: -0.007407407407407418 \ Subjectivity: 0.38518518518518524
# .....................
# Tweet: Kat with two slams 💪 https://t.co/xh6ko9MJxA
# Polarity: 0.0 \ Subjectivity: 0.0
# .....................
# Tweet: @BR_NBA @ThompsonScribe https://t.co/wZ9390bVcJ
# Polarity: 0.0 \ Subjectivity: 0.0
# .....................
# Tweet: https://t.co/8bgnfutz1Y
# Polarity: 0.0 \ Subjectivity: 0.0
# .....................
# Tweet: @IcySimmons @NBA Embid game is soooooo much better bro for sure. Embiid can shoot from anywhere and has so many pos… https://t.co/5jUN7tFceJ
# Polarity: 0.275 \ Subjectivity: 0.5722222222222222
# .....................
# Tweet: I don't think we are talking enough about how Vince Carter played for the Hawks last night (and all season), then c… https://t.co/pvfr0YQrrq
# Polarity: 0.0 \ Subjectivity: 0.2833333333333333
# .....................
# Tweet: Follow NBA, NFL, and MLB live! @ClutchPointsApp https://t.co/BRcy5aBkxr
# Polarity: 0.17045454545454544 \ Subjectivity: 0.5
# .....................
# Tweet: @colbeyyy You’re on my mind
# Polarity: 0.0 \ Subjectivity: 0.0
# .....................
# Tweet: @TheHerd @RicBucher Remember: Bucher was the one who first broke that LeBron going back to Cleveland was a done dea… https://t.co/QWNvEOKLPu
# Polarity: 0.125 \ Subjectivity: 0.16666666666666666
# .....................
# Tweet: #NBA
#
# Que alguien le diga a @TheTraeYoung que los Ice Trae Adidas N3XT L3V3L, están bien feos...🤷🏻‍♀️😂😂😂😂😂 #IceTrae… https://t.co/ZRMMp03j4c
# Polarity: -0.9099999999999999 \ Subjectivity: 1.0
# .....................
# Tweet: @37Wolves @MackGeorge1315 @NBA jokic is 100% better.
# Polarity: 0.5 \ Subjectivity: 0.5
# .....................
# WEIGHTED MEAN: -0.02917393718771229
# NEGATIVE
# MEAN: 0.05084362139917695
# POSITIVE
